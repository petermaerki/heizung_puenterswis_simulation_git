# %% [markdown]
# # Die erste Simulation

# %%
# %matplotlib inline

import main
stimulus_first = main.Stimulus()
simulation_first = main.Simulation(stimulus_first)
simulation_first.do_simulation()
simulation_first.plot()
